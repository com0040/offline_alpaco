# %% [markdown]
# <a href="https://colab.research.google.com/github/com0040/offline_alpaco/blob/main/22_11_18_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%9D%B8%EC%8B%9D_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 전처리 하는 이유를 아는게 중요하다
#
# - 성능개선을 위한 것이다.
#
# 왜 쓰는지 알면 오픈소스의 도움으로 사용하는건 어렵지 않다.
#
# 하드코딩 할 필요는 없다.

# %% [markdown]
# # 빠르게 훑고 가자
#
# 인공지능 - 사람처럼 움직인다 (겉으로 보고 안다)
#
# 딥러닝 <-> 머신러닝 : ai
#
# 1. 규칙기반 : 도메인 지식이 중요하다.(Rule-based)
#
# 2. 학습기반 : 데이터 학습기반 스스로 학습
#
# 이세돌을 어케이겻누?
#
# - 강화학습 : 1) 보상시스템 2) 데이터 증축
#
#     - 이긴 수에 대해 보상 / 진 데이터 = 패널티
#
# 머신러닝의 두가지 정의
#
# 1. 아서 사무엘 : 정교한 프로그래밍 없이 컴퓨터를 학습시키는 것.(규칙기반)
#
# 2. 턴 미쉘 : 데이터(경험)로부터 학습하는 것이다.
#
# - 정교한 프로그래밍(규칙) 없이 데이터(경험)으로 기계가 학습하는 것.
#
# ---

# %% [markdown]
# # 무엇을 학습하는가? - 웨이트
#
# - 하이퍼티디즈를 잘 찾아야 -> 웨이트를 업데이트하면서 코스트가 낮은 웨이트를 찾는다.
#
# - 웨이트라고 말할 수 있는 이유 : 하이퍼티디즈를 정했기 때문에
#
# 1. 딥러닝을 할거야 -> 하이퍼티디즈를 정해준거다.
#
# 2. 무슨 모델? => 미지수는 구해준다. 알렉스 넷으로 할거야
#
# 3. 가장 단순한 것을 생각하는 사람
#
# - 상관관계를 만족하는 방정식은 많다.
#
# ---

# %% [markdown]
# # 정해줄건 정해주고 가자
#
# - 선형적이라고 정해주고 찾으라고 한다.

# %% [markdown]
# ## 경험을 채택하는 것이 머신러닝
#
# 1. 하이퍼티디즈
#
# 2. 웨이트
#
# 3. 코스트
#
# - 지도 / 비지도 : 목적이 다르다.
#
#     - Y값의 유무보다 목적에 따라.
#
#     - 왜 지도학습? = 예측
#
#     - x끼리 학습시켜서 얻을 수 있는것? 무엇일까?
#
# 지도 1) 회귀 2) 분류
#
# 비지도 ->
#
#     비슷한 애들끼리 묶는다 - 클러스터링
#
#     비지도 변환 이미지 생성 - 새로운 x를 만들어낸다.
#
# Y 값의 여부 -> 지도 비지도

# %% [markdown]
# # 그럼 어떻게 학습해?

# %% [markdown]
# 웨이트 업데이트
#
# 초기값 -> 기울기 확인 -> 업데이트
#
# - 반복 기울기가 0일때 까지 = 기울기만 0?
#
# - 코스트가 최소인지 안본다.
#
#     1. 계산량이 많아져서 웨이트에 대한 코스트값을 다 찾을 수는 없다.
#
# - 코스트 함수 (컨벡스) 하게 조정 가능하다면 그렇게 하지만
#
# - 개념설명은 뒤로 미뤘다.
#
# - 이 것을 해결하는 방법론 : 옵티마이저
#
# -

# %% [markdown]
# ## cost function이 언제 non - convex 해지냐
#
# 오차함수 - cost 함수
#
# 1. hypotisis 복잡 -> cost 복잡하다 (non - convex) -> 복잡한 옵티마이저를 사용(GDA)
#
# 2. 딥러닝이 hypothisis는 복잡 -> cost 복잡 -> 복잡한 옵티마이저를 써야한다.
#
# - 트레인셋 로컬미니멈에 도달하면 : 언더핏이다.
#
# 학습단계에서 로컬미니멈에서 코스트가 크다는 것이다. = 학습을 잘 못했다.

# %% [markdown]
# ## 로컬미니멈 어케하누
#
# 글로벌 미니멈 근처에 초기값
#
# 연구자의 노력 - 이해하는 것만으로 인사이트

# %% [markdown]
# # 머신러닝의 성능향상

# %% [markdown]
# 학습 검증
#
# - 데이터 분리
#
# - 검증 신뢰도 ( k - fold / 10 C 2 = 45)

# %% [markdown]
# ### 힉습을 잘한다는 것?
#
# 1. 오차 최소화
#
# 2. 일반화
#
#
# 컴퓨터가 잘 학습시키기위해서 그러면 어떻게?
#
# - 경향 : 사람 친화적 표현이다 ( 문제복잡도에 절절한 복잡도를 가지고 학습해
#
# ⏰ 그러면 모델 복잡도의 수치를 알려줘야한다.
#
# 웨이트의 크기 = 모델 복잡도를 대표
#
# - 규제 : 오차와 모델복잡도 동시에 잡기
#
# 민 코스트 웨이트 : 오차 + 모델복잡도
#
# ---
#
# 왜 나만가지고 그래(모델)
#
# 데이터 건드려
#
# 데이터 핸들링 <-> 모델 핸들링

# %% [markdown]
# # 딥러닝

# %% [markdown]
# 인공신경망 = 다층 퍼셉트론(MLP) = 뉴럴 네트워크
#
# 퍼셉트론>?
#
# - 뉴런 : 입력 - 계산 - 출력 ( 단순)
#
# - 퍼셉트론 : 단순화 (X 입렵값 - 가중합 -> 활성화 함수 -> Y)
#
#     1. 로지스틱과 비교 - 확률적 선형모형
#
#     퍼셉트론은 비확률적 모형 : 0,1 이므로
#
# 분류 1)  확률 2) 비확률
#
# ---

# %% [markdown]
# 하이퍼티디즈
#
# - 선형
#
# - 비확률적 -> 읽을줄 알아야함
#
# 식을보고 도식화 가능?>
#
# 연습하자
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 학습을 하는 w 가 화살표에 있다는 것을 받아들여.
#
# $ w_1x_1 + w_2x_2 +b = WX $

# %% [markdown]
# ## 하나의 뉴런은
#
# - 선형 연산 = 분류기
#
# - 출력이 있어나 없거나
#
# 퍼셉트론은 비 확률적 선형 분류기 !!
#
# - hypothisis 를 해석 햇을 때

# %% [markdown]
# ### 모델을 컴팩트하게 공부
#
# - 하이퍼 티티즈 공부
#
# - 코스트 어케구해

# %% [markdown]
# ## 오차는 어케 하려나
#
# 실제값과 오차값이 같거나 반대 값 밖에 없다.

# %% [markdown]
# 로그 로스랑 다르게
#
# 오차가 0 과 1 뿐이다.
#
# - 확률적 모형이 아니라 로그 로스를 쓸 수 없다.
#
# - 아쉽 : 틀렸을때 가중치가 1뿐(로그로스랑 다르게)
#
# - 제곱합으로 오차를 계산 : 데이터 갯수에 비례

# %% [markdown]
# ## 다층 퍼셉트론 (multi layer perceptron)
#
# - 멀티 레이어

# %% [markdown]
# 선형을 비선형으로 = 멀티 레이어의 뜻

# %% [markdown]
# ### 퍼셉트론의 한계
#
# - AND 연산 가능? = 1과 0 구분 가능?
#
# - 선형 구분 가능 = 퍼셉트론이 가능하는 것이다.
#
# - 비선형은 퍼셉트론으로 불가능 - 비선형 경계선 필요
#
# 벗!

# %% [markdown]
# ### 다층 퍼셉트론으로 비선형을 해결하겠다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 여러층을 쌓겠다는 것이다.
#
# - 왜 비선형으로 가능해 지는거?
#
# 다층일 뿐인데?

# %% [markdown]
# 최종적으로는 1-0 나오는 것인데
#
# - 앞부분을 보면 활성화
#
# - 경계선을 만드는데 비선형함수가 사용되면ㄴ 비선형 분류 가능이다
#
# 1. 경계선을 그리고
#
# 2. 분류
#
# 1 과정에 비선형 함수가 사용되어야 비선형 방정식이 된다.

# %% [markdown]
# ### 활성화 함수가 중간에 들어가서
#
# - 비선형 분류기가 된다.
#
# - 활성화함수가 선형이라면 선형 분류기가 된다.

# %% [markdown]
# ### 재밌는 딥러닝
#
# 1. 귀납적
#
# 2. 스토리 텔링이 있다
#
# - 로지스틱 -> 선형
#
# - 디시즌트리 -> 비선형
