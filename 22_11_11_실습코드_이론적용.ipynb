# %% [markdown]
# <a href="https://colab.research.google.com/github/com0040/offline_alpaco/blob/main/22_11_11_%EC%8B%A4%EC%8A%B5%EC%BD%94%EB%93%9C_%EC%9D%B4%EB%A1%A0%EC%A0%81%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 데이터 전처리 - train test split
#
# shuffle - 데이터 섞기
#
# stratify - 데이터 분리 후 내부 라벨 비율 맞추기

# %% [markdown]
# 2. fit
#
# 학습 원리
#
# 1) weight 초기값 2) cost 계산 3) cost의 기울기로 weight 업데이트

# %% [markdown]
# 3. weight, bios
#
# coef = weight
#
# intercept = bias

# %% [markdown]
# 규제
#
# penalti - norm 놈(벡터의 크기 - 제곱)
#
# C = 규제의 역수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# malti class
#
# multi_class = ovr ->
#
# multi_calss = 'multinomial' -> 소프트 맥스

# %% [markdown]
# # 디시즌 트리 실습
#
# 가시화 확인
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 트리 그림 비교할 줄 알아야함
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 특성 중요도
#
# 이걸 뽑으려고 디시즌트리를 사용하기도 한다.
#
# - 로지스틱 리그레션에서는 weight가 피처 임포턴스다.
#
# - weight는 방향성까지 있는데 특성중요도는 엔트로피를 낮추는데 영향을 주었다만 있음

# %% [markdown]
# 디시즌트리 리그레서
#
# `criterion =` 'mse' # mesn squre error
#
# 편차 에러 = mse
#
# avg 차이 = 편차
#
# 편차가 왜 에러인가???
#
# - 디시즌트리 회귀는 예측값을 마지막 분리된 트레인 셋의 평균으로 한다.
#
# 학습 = min square error가 최소가 되는 질문을 찾는다.
#
# ---
#
# 기존은 엔트로피를 낮추는 질문
#
# - 엔트로피는 무엇인가
#
#     - 집단이 카테고리일때에 가능한 것이다.(강아지 몇마리 고양이 몇마리 = 불순도)

# %% [markdown]
# # 랜덤 포레스트

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 오른쪽이 랜덤포레스트
#
# - 일반화 했다.

# %% [markdown]
# # 에이다 부스트

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 누가 에이다 부스트? vs 랜덤 포레스트
#
# - 파랑이 : 랜덤 포레스트
#
# 주황이 에이다 부스트
#
# - 버릴건 버린다.
