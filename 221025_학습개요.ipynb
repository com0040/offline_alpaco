# %% [markdown]
# <a href="https://colab.research.google.com/github/com0040/offline_alpaco/blob/main/221025_%ED%95%99%EC%8A%B5%EA%B0%9C%EC%9A%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이원재 담당 교원
#
# 16년 - ai 교육(현재)
#
# sk플래닛 -> skt -> tlp(추천 시스템 개발)
#
# 딥러닝 -> 이미지 / 자연어(택스트) / 추천 시스템(?) : 배타 독립적
#
# 자연어 -> 클로바 때문에 무산 / 강의를 타이핑, 요약 -> 강의 요약 api 개발(상용화 한계)
#
# CV(이미지) -> 쇼핑몰 가상아바타(옷 입히기) : 의류 잘 맞나 - 2D 사진 -> 3D 아바타 (이미지 합성 프로젝트) / RND성(상용화X)
#
# TMI : 상용화 X
#
# 생존형 강의 / 국비과정 18-19년 시작(장기간 -> 보람, 운영은 어렵)
#
# 수강생들의 이직 관심 많다. (취업 -> 잘 오셨다.)
#
# 알고리즘 테스트 -> 취업(체계화된 취업 시스템 : 실력 나뉜다. 정량화) / 국내 ? 국외(페북, 구글)
#
# 플러스(포트폴리오, 면접)
#
# AI쪽 -> 알고리즘을 잘짜는 것(?) : 배타적이다. / 서류, 면접으로만 하니 오류남
#
# 19년 : ADSP 자격증, 통계 대답, 포트폴리오 -> 20년부터 막혔다.(기업이 체계화에 성장)
#
# AI 역량 평가를 위한 체계화(생길 것이다.) : 테스트 생길 것이다.
#
# 의견 분분, 가장 유력한 것이 keggle, -> 정확도(accuracy)를 이용해서 평가가 가능
#
# 코드 제출 -> test set의 정확도를 평가 / 90점 85점 95점
#
# 문제는 - 기업이 데이터를 준비해야하는 수고 / ADSP 자격증 실습문제(빈칸코드 - 채점 어려움)
#
# 둘다 생겼다(후자 - sk 네트웍스 : 살아남지 못함 / 체점시스템에 문제)
#
# 어떤 코드를 짜야하는지 -> 자격증 형태
#
# keggle - 코드 / 데이터 : 정확도 -> 자리잡을 것이라고 생각된다.
#
# 알고리즘 테스트처럼 정형화, 정량화 가능 -> 실력을 정량화 정형화 (앞으로도 유지)
#
# 1. 기본 코딩 실력 2. AI 테스트 -> 보통 + 포트폴리오(2가지로 평가 불가한 것들)
#
# 우리(알파코) 해야할 것 - 명확하게 알려줌 / 알고 시작하는 것은 다르다.
#
# 6개월 / 비전공자 / 파이썬 처음 - 가능할까? (해보자 - 불안, 신뢰)
#
# 고민은 무의미하다. (빨리 결정해야하는 사람이 아니면 해보자.)
#
# 갈아넣어 보자. (제가 하니까 확률은 낮아요 ㅎ)
#
# 오해하는 사실 : 코딩은 적성이 중요하다(= 재능이 중요하다.) 탑티어는 그렇다.
#
# 의사, 축구선수, 피겨 마찬가지 -> 수능을 잘본거지 의학공부는 처음이었다.
#
# 코딩은 그것보다 쉽지 않을까? - 그렇다.
#
# 머리가 좋다 -> 빠르게 잘 하는 거다. but 취업 수준은 누구나 가능하다.
#
# 내가 이길이 아니다? -> 6개월은 해봐야 안다.(최선을 다해봐야 - 2달? 1달? X)
#
# 일단 노력하기전 적성,재능 따지지 말자.
#
# 이영표 '재능은 찾는 것이 아니라 만들어 지는 것이다.'
#
# 1기 involve / 2기 : 가장 잘 하는 분 (30후반) 잘하고 있다
#
# 2기 - keggle : 3조, 반 전체 3,4명(부끄러운 컴공생), 1-2명(열심히)
#
# 3기 - daycon(200몇팀) : 공부한지 4개월 3명 다 비전공(1등 - 전국 중 일등) - 1명 버스
#
# 역량은 길러지면 된다. 출발점은 다르지만, 열심히!
#
# 모든 것은 훈련으로 극복 가능 하다.
#
# 직관 - 공부해야 할 것이 많다.(패스트 트랙으로 가야하기 때문에)
#
# 필요한 것만 공부 -> 취업을 할 수 있는 역량
#
# 장기 프로젝트로 넘어가서 길러야할 것들 있는데
#
# 2개월간 역량을 강화해야하는 부분들
#
# 1. 알고리즘 테스트 (스터디 꾸릴 것이다.)
#
# 2. AI 테스트 대비 - 수업을 통해서 / 성능을 개선시키는 법을 배워야한다.
#
# 프로젝트로 넘어가서
#
# 3. 포트폴리오
#
# 경진대회 -> 예측 모델의 성능 개선 : 기본적인 성능을 넘어서서 / 얼마나 개선 시킬 수 있는가 - 그것을 배울 것이다.(성능 개선 역량을 기를 것이다.)
#
# 목표 : 최대한 단기로 / 성능 개선 (차별화는 거기있다. / 어떤 부트캠프 - 이것저것 : 목표가 없이 중요하다고 넣어두면 - 소화 불가)
#
# 명확한 목표를 두고 필요한 것들만 가르칠 것이다. -> 반드시 알아야 하는 것들은 최대한 쉽게 알려 줄 것이다.
#
# 직관적인 이해 -> 수학 (말도안되 - 수식을 다 알아야하는 것은 아니야 / 수식노름 X) : 논리적 사고로 수업
#
# 그 다음 - 이해한 개념을 코드로 구현하려고 배운다. (코드로 구현 불가한 것은 '스레기')
#
# 코드로 구현하는 훈련 - 무조건 (그 시간이 더 있어야 한다.) / 코드로 구현하는 시간이 압도적으로 많아야함.
#
# 초반엔 개념 위주 / 나중엔 8대2 / 설명은 최대한 압축(시간 압축) : 남는 시간은 코드 찍는 법 위주로
#
# 이해할 것은 이해, 암기 할 것은 암기 : 유지할 수 있어(빠르게 암기하기 위해)
