# %% [markdown]
# <a href="https://colab.research.google.com/github/com0040/offline_alpaco/blob/main/22_12_06_%EA%B0%9D%EC%B2%B4%EC%9D%B8%EC%8B%9D_%EB%A6%AC%EB%B7%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) 객체인식

# %% [markdown]
# 욜로 모델에 집중 할 것이다.
#
# - low level cue -> 아닌부분 날려
#
# 바운딩 박스와 라벨을 알아내는 작업(시각화)

# %% [markdown]
# ## ㄱ)어떻게 할까

# %% [markdown]
# 라벨과 위치 모두 예측
#
# - 코드화
#
# 1. 특정 이미지 예측에서 객체라벨 예측 - 분류
#
# 2. 위치는 어떻게 알아내? - 회귀
#
# 위치
# - x y w h

# %% [markdown]
# ## ㄴ) 이해하기로

# %% [markdown]
# 피처맵이 분류와 회귀에 더 낫다
#
# 분류 - 분류하기에 더 나은 사본 = 피처맵
#
# 회귀 - 회귀하기에 더 나은 사본 = 피처맵
#
# 위치정보의 기준
#
# - 중심점의 위치
#
# - 너비와 높이

# %% [markdown]
# ## ㄷ) 라벨은 같은 원리

# %% [markdown]
# 라벨 예측은 그대로 가도 된다.
#
# 거기에 위치만 예측할 수 있도록

# %% [markdown]
# ## ㄹ) 객체가 여러개라면?

# %% [markdown]
# 모델을 여러개 써야하므로 object localization의 한계
#
# 돌파구
#
# 1. Object Detection
#
# 2. Image Segmentation

# %% [markdown]
# ## ㅁ) Ovject Detection 위주로 알아보자

# %% [markdown]
# 슬라이딩 윈도우 -> 계산복잡도 높다(전체구역, 윈도우 사이즈별)
#
# 있을만한 곳을 연구하자.

# %% [markdown]
# ## ㅂ) 옵젝트 디텍션의 종류

# %% [markdown]
# 2-stage model = RCNN
#
# 1-stage model = yolo

# %% [markdown]
# v1,2,3,4 까지 볼것
#
# 5,6 - 적용가능하지만 도큐맨트는 없다.

# %% [markdown]
# ## ㅅ) Convolutional 연산을 알아야 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 욜로의 이해를 돕기 위함이다.
#
# - 객체의 위치
#
# 영역제한 x, 한번에 수행하는 것?
#
# 접근법을 고민
#
# convolutional 만으로 전체 이미지의 위치에 접근 가능하다.
#
# 바운딩 박스를 그리는 용은 아니고 객체가 있구나만 알수 있다.

# %% [markdown]
# # 2) 평가지표

# %% [markdown]
# mean average presision
#
# inference time

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 복습 ㄱㄱ

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 강아지 AP / 고양이 AP -> 평균낸 것 = mAP

# %% [markdown]
# recall 값이 증가하는 방향
#
# - 바운딩 박스를 하나씩 그리는 방향
#
# 모든 객체를 검출할때 까지 진행
#
# 다음 에폭에서 틀렸을 경우 - 리콜은 그대로 프리시즌 감소
#
# precision - 1/1 -> 2/2 -> 2/3 -> 2/4
#
# recall - 1/5 -> 2/5 -> 2/5 -> 2/5

# %% [markdown]
# ### 그런데 맞춘것에 기준이 필요하다

# %% [markdown]
# IOU = 합집합 중 교집합 > 0.5
#
# 오해 x -> 전체 면적중 교집합이 절반이어야함
#
# coco AP 기준을 엄격하게 해보면서 적용
